# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
for doc in \
    client.vectordb.company_key_data.find({
        'topic': 'G',
        'metric': True
    }):
    break

# %%
client.vectordb.company_key_data.distinct('company')
# Out:
# ['Advanced Micro Devices, Inc.',
#  'Apple Inc.',
#  'Intel Corporation',
#  'Microsoft Corporation',
#  'NVIDIA Corporation',
#  'Qualcomm Incorporated']

# %%
pipeline = [
    {
        '$match': {
            'tags': {'$regex': 'diversity', '$options': 'i'},  # Match documents based on query
            'metric': True,
            'company': 'NVIDIA Corporation',
            'topic': 'G'
        }
    },
    {
        '$addFields': {
            'descriptionLength': {'$strLenCP': '$description'}  # Add a field for the length of the description
        }
    },
    {
        '$sort': {'descriptionLength': 1}  # Sort documents by the length of the description in ascending order
    },
    {
        '$limit': 2  # Limit the result to
    }
]

# Execute the aggregation pipeline
results = client.vectordb.company_key_data.aggregate(pipeline)

# Print each document found
for document in results:
    print(document['value'], document['description'])
# Out:
# 23% Percentage of Board members who are women.
# 12.0% Percentage of leaders who are women in FY22.

# %%
def get_metrics(company, topic, phrase):
    pipeline = [
        {
            '$match': {
                'tags': {'$regex': phrase, '$options': 'i'},  # Match documents based on query
                'metric': True,
                'company': company,
                'topic': topic
            }
        },
        {
            '$addFields': {
                'descriptionLength': {'$strLenCP': '$description'}  # Add a field for the length of the description
            }
        },
        {
            '$sort': {'descriptionLength': 1}  # Sort documents by the length of the description in ascending order
        },
        {
            '$limit': 2  # Limit the result to
        }
    ]

    # Execute the aggregation pipeline
    results = client.vectordb.company_key_data.aggregate(pipeline)

    # Print each document found
    return_res = []
    for document in results:
        return_res.append({'value': document['value'], 'description': document['description']})
    return return_res

# %% [markdown]
# ## Environmental

# %%
# Energy efficiency
get_metrics('NVIDIA Corporation', 'E', 'efficiency')
# Out:
# [{'value': '3,492 gigajoules',
#   'description': 'Reductions in energy consumption'},
#  {'value': '20 percent',
#   'description': 'Reduction in emissions per employee since FY14.'}]

# %%
# renewable energy
get_metrics('NVIDIA Corporation', 'E', 'renewable')
# Out:
# [{'value': '154,160 MWh',
#   'description': 'Renewable electricity purchased in FY22.'},
#  {'value': '38%', 'description': 'Renewable electricity percentage in FY22.'}]

# %%
# Emissions
get_metrics('NVIDIA Corporation', 'E', 'emissions')
# Out:
# [2,074,450] Scope 3 (tCO2e) in FY21.
# [91,740 tCO2e] Scope 1 and 2 emissions.
# [0.19 metric tons] Metric tons of VOC emitted.
# [0.16 metric tons] Metric tons of SOX emitted.
# [119] Gasoline emissions in FY19.
# [102,026] Capital goods (tCO2e) in FY21.
# [2 mtCO2e] Metric tons of methane emitted.
# [118] Refrigerants emissions in FY19.
# [3,068] Business travel (tCO2e) in FY21.
# [14,764] Employee commuting (tCO2e) in FY21.
# [0.17 metric tons] Metric tons of particulates emitted.
# [2 mtCO2e] Metric tons of nitrous oxide emitted.
# [3,327 mtCO2e] Metric tons of carbon dioxide emitted.
# [0.51 metric tons] Metric tons of carbon monoxide emitted.
# [12,357] Upstream leased assets (tCO2e) in FY21.
# [91,740] Scope 1 and 2 emissions (tCO2e) in FY21.
# [105,621] Scope 2, location-based (tCO2e) in FY21.
# [2,379] Stationary natural gas emissions in FY19.
# [1.4 metric tons] Metric tons of hydrofluorocarbon emitted.
# [2,671] Total global GHG emissions (tCO2e) in FY19.

# %%
# Waste Management
get_metrics('NVIDIA Corporation', 'E', 'waste')
# Out:
# [56%] Landfill diversion rate in FY22.
# [80 percent] Annual goal for landfill diversion.
# [411] Metric tons of waste landfilled in FY22.
# [78 percent] Landfill diversion rate achieved in FY20.
# [577] Waste generated in operations (tCO2e) in FY21.
# [224] Metric tons of general waste landfilled in FY22.
# [2] Metric tons of hazardous waste recycled in FY22.
# [75] Metric tons of electronic waste recycled in FY22.
# [80 percent] Annual goal for landfill diversion at headquarters since FY08.
# [80 percent] Landfill diversion rate for Silicon Valley headquarters campus.
# [80%] Landfill diversion rate for Silicon Valley headquarters campus.
# [186] Metric tons of construction/demolition waste landfilled in FY22.
# [80%] Waste-to-landfill diversion rate at Silicon Valley headquarters.
# [80%] Waste-to-landfill diversion rate at Silicon Valley headquarters.
# [Percentage (%)] Percentage of hazardous waste from manufacturing that is recycled.
# [80 percent] Waste-to-landfill diversion rate or greater each year at our Silicon Valley headquarters.
# [56%] Percentage of FY22 waste diverted from landfill, a 12 percentage point decrease from the previous year.
# [90%] Percentage of headquarters waste that was either recycled or composted in FY19, with only 10% going to landfill.
# [Amount of hazardous waste from manufacturing] Amount of hazardous waste generated from manufacturing, including percentage of hazardous waste that is recycled.
# [68%] Percentage of waste diverted overall in FY21, with 62% of operational waste and 71% of construction project waste diverted.

# %%
# water
get_metrics('NVIDIA Corporation', 'E', 'water')
# Out:
# [A-] CDP score for climate change and water security responses.
# [42 percent] Reduction in domestic water demand in new headquarters building.
# [42 percent] Reduction in domestic water demand in new headquarters building.
# [91 percent] Reduction in potable water use for sewage conveyance in new headquarters building.
# [91 percent] Reduction in potable water use for sewage conveyance in new headquarters building.
# [Percentage (%)] Percentage of water consumed in regions with High or Extremely High Baseline Water Stress.
# [Percentage (%)] Percentage of total water withdrawn in regions with High or Extremely High Baseline Water Stress.
# [carbon emissions and water consumption per product and per financial outlay] Metrics calculated by NVIDIA to determine the environmental impact of its products and financial outlay.
# [46 percent] Less potable water used in new headquarters building compared to other campus buildings of a comparable size.
# [Thousand cubic meters (m³)] Total water withdrawn by NVIDIA, a fabless semiconductor company that does not have its own manufacturing facilities.
# [Total water withdrawn] Total amount of water withdrawn, including percentage of water withdrawn in regions with High or Extremely High Baseline Water Stress.
# [carbon, water, waste data] Calculated carbon, water, and waste data of all silicon manufacturers and systems contract manufacturers to determine carbon emissions and water consumption per product and per financial outlay.
# [carbon emissions] Calculating carbon, water, and waste data of all silicon manufacturers and systems contract manufacturers to determine carbon emissions and water consumption per product and per financial outlay.
# [water withdrawn] Total water withdrawn and percentage of total water withdrawn in regions with High or Extremely High Baseline Water Stress, and percentage of water consumed in regions with High or Extremely High Baseline Water Stress.

# %% [markdown]
# ### Social

# %%
# Gender Diversity
get_metrics('NVIDIA Corporation', 'S', 'gender')
# Out:
# [5.7%] Turnover rate for men in FY19.
# [5.6%] Turnover rate for women in FY19.
# [80.9] Percentage of men in the workforce.
# [18.9] Percentage of women in the workforce.
# [80.4%] Percentage of male employees in FY22.
# [19.0%] Percentage of female employees in FY22.
# [80.5%] Percentage of men in the workforce in FY20.
# [11.0%] Percentage of leaders held by women in FY19.
# [16.5%] Percentage of managers held by women in FY19.
# [18.9%] Percentage of women in the workforce in FY20.
# [20.4%] Percentage of female employees in the company.
# [18.0%] Percentage of outside directors held by women in FY19.
# [19.1%] Percentage of new hires globally who are women in FY22.
# [40.0%] Percentage of executive officers held by women in FY19.
# [0.94%] Percentage of employees who did not declare their gender.
# [16.8%] Percentage of women promoted in FY22, compared to 15.7% of men.
# [0.21%] Percentage of employees who did not declare their gender in FY19.
# [0.6%] Percentage of employees who did not declare their gender in FY20.
# [364] Number of women promoted in FY20, making up 19 percent of all promotions.
# [11.3 percent] Percentage of women promoted in FY19, equal to the percentage of men promoted.

# %%
# Diversity
get_metrics('NVIDIA Corporation', 'S', 'diversity')
# Out:
# [265] Number of women hired globally.
# [29%] Percentage of workforce from China.
# [19%] Percentage of workforce from Europe.
# [8%] Percentage of workforce from Europe.
# [25%] Percentage of workforce from Taiwan.
# [13%] Percentage of workforce from Europe.
# [10.5%] Percentage of leaders that are women.
# [80.4%] Percentage of male employees in FY22.
# [11.3%] Percentage of leaders that are women.
# [15.9%] Percentage of managers that are women.
# [38.70%] Percentage of White employees in FY19.
# [16.2%] Percentage of managers that are women.
# [19.7%] Percentage of new hires that are women.
# [19.0%] Percentage of female employees in FY22.
# [6.7%] Turnover rate for men in the past year.
# [6.9%] Turnover rate for women in the past year.
# [40 percent] Increase in female speakers at GTC in 2019.
# [5%] Percentage of workforce from United States.
# [20%] Percentage of workforce from United States.
# [5%] Percentage of workforce from United States.

# %%
# Inclusion
get_metrics('NVIDIA Corporation', 'S', 'inclusion')
# Out:
# [1.4%] Percentage of veterans in the U.S. in FY22.
# [2.1%] Percentage of employees with disabilities in the U.S. in FY22.
# [100%] Percentage of diverse hires tracked through the recruiting funnel.
# [21,000] Number of people reached through developer conferences in seven countries.
# [87 percent] Percentage of employees who say that our teams value diverse perspectives.
# [tripled] Number of Black and African American employees increased in the past year.
# [507] Number of promotions given to members of minority groups in the U.S. in FY19.
# [50 percent] Increase in female attendance at the GPU Technology Conference (GTC) in 2019.
# [6] Number of years in a row that GTC has included events specifically for women.
# [tripled] Increase in Black and African American employees in the U.S. in the last year.
# [2,000] Number of Mellanox employees welcomed from Israel and the Palestinian Authority.
# [24] Number of underrepresented communities in technology that have been hired in FY21.
# [50%] Percentage of unconscious bias programming implemented in team dynamics activities.
# [30 African developer community groups] Number of African developer community groups that joined Emerging Chapters in FY22.
# [60 percent] Increase in the number of women attending NVIDIA's November event from the year prior.
# [7th] Consecutive year scoring 100% on the Human Rights Campaign’s Corporate Equality Index.
# [HIRING] Metric used to track diversity and inclusion progress in hiring of women and minorities.
# [95%] Training materials created and rolled out during FY20 to promote diversity and inclusion.
# [19,000] Number of underrepresented candidates reached at university and professional recruiting events.
# [47,000] Number of underrepresented candidates reached through university and professional recruiting events.

# %%
# Education
get_metrics('NVIDIA Corporation', 'S', 'education')
# Out:
# [tens of thousands] Number of developers educated each year.
# [1,000] Number of courses using GPUs being taught in universities worldwide, supported by NVIDIA.
# [10,000 more K-12, community college, and HBCU students] Number of students who will have access to AI curriculum through the AI Education Project investment.
# [1.3 million] Amount donated by NVIDIA and its employees to education efforts in FY19, reaching nearly 80,000 youth.
# [several hundred] Number of students from the Santa Clara Unified School District engaged through the Techsplorer program.
# [50 women] Number of women given access to deep learning courses through the Women's Early Career Accelerator program.
# [10,000] Number of students reached by NVIDIA's Techsplorer kits through the AI Family Challenge initiative since its launch in FY18.
# [Grants for Developer Kits] Number of Jetson Nano developer kits given to educators in colleges, schools, and nonprofit groups as part of a grant program.
# [9] Number of organizations receiving funding and virtual volunteer events for supporting youth from underserved communities in developing STEM skills.
# [4,300] Number of youth engaged through activities designed to help them excel in basic math skills and gain inspiration through tours of NVIDIA's technology center and career roundtables with NVIDIA engineers.
# [3,000] Number of young women from impoverished communities in India who gained greater access to computer training and developed skills to improve their career opportunities through funding from the India Companies Act.
# [4,300] Number of youth engaged through activities designed to help them excel in basic math skills, be inspired through tours of technology center and career roundtables with NVIDIA engineers, and get access to innovative AI technology through hands-on activities.

# %% [markdown]
# ### Governance

# %%
# Compliance
get_metrics('NVIDIA Corporation', 'G', 'compliance')
# Out:
# [13] Number of suppliers engaged on their CAPs from the FY21 auditing season.
# [100%] Percentage of strategic suppliers that completed self-assessment questionnaires (SAQs).
# [100%] Percentage of NVIDIA's SAQ review that determined no high-risk suppliers in the top spending area.
# [60%] Anti-bribery policy update in process and anti-trust policy being finalized for roll out during FY20.
# [100 percent] Percentage of employees who complete code of conduct training upon hire and every two years thereafter.
# [0%] Percentage of suppliers that required corrective action plans (CAPs) due to lack of high-risk suppliers.
# [100%] Percentage of employees who had completed code of conduct, ethics, and sexual harassment training as of March 2022.
# [100%] Percentage of strategic suppliers that completed self-assessment questionnaires (SAQ) in the top 80% of NVIDIA spending.
# [100%] Percentage of processing facilities in supply chain that are compliant with Responsible Minerals Assurance Process (RMAP).
# [100%] Percentage of suppliers ranked for compliance with RBA Code of Conduct, leveraging RBA membership and using RBA-Online platform.

# %%
# Supply Chain
get_metrics('NVIDIA Corporation', 'G', 'supply')
# Out:
# [100%] Percentage of processing facilities in supply chain that are compliant with Responsible Minerals Assurance Process (RMAP).
# [100%] Percentage of suppliers ranked for compliance with RBA Code of Conduct, leveraging RBA membership and using RBA-Online platform.

# %%
pipeline = [
    {"$unwind": "$tags"},
    {"$group": {"_id": "$tags"}},
    {"$group": {"_id": None, "uniqueValues": {"$push": "$_id"}}},  # Collects all unique values into a single array
    {"$project": {"_id": 0, "uniqueValues": 1}}  # Optional: Formats the output to only show the array of unique values
]

unique_values = client.vectordb.company_key_data.aggregate(pipeline)

# Assuming you want to print the array of unique values
for value in unique_values:
    for tag in value['uniqueValues']:
        print(tag)
# Out:
# environmental data
# Circular Centers
# sustainable energy
# sustainable IT practices
# carbon avoidance
# compensation committee
# supplier recognition
# data management
# inclusive culture
# management review
# instructional design
# ESG data summary
# supplier management
# environmental
# SBTI
# processors
# IT
# supercomputing
# toxicology
# speed
# environmental justice
# ethics
# share repurchase
# justice
# STEM
# CSR recognition
# financial data
# material challenges
# cloud migration
# CSR
# manufacturing sites
# biometrics
# social goals
# child labor
# rewards and recognition
# community development
# responsible minerals
# employee resource groups
# chemical substances
# gpu
# server
# partnerships
# sustainable solutions
# customer satisfaction
# gender imbalance
# supplier audit
# economic opportunity
# iOS
# sustainable development
# inclusive
# public policy engagement
# messaging
# 2030
# disability inclusion
# renewable integration
# predictive modeling
# GPU-powered
# environmental regulations
# climate science
# engagement
# waste management
# csr report
# community impact
# programming
# routing system
# inclusive benefits
# COVID-19 relief
# health hazards
# lifecycle
# credibility
# carbon tracking
# projects
# water policy
# international partnerships
# climate risk
# digital economy
# WEF
# leadership accountability
# competition law
# e-waste
# financial benefits
# safety procedures
# safety standards
# supplier diversity
# financial reporting
# employee relations
# beryllium
# tropical forest
# future goals
# wellness
# program
# industrial solutions
# energy efficiency
# research
# expansion
# indirect emissions
# child safety
# global participation
# design-thinking
# ambassador
# responsible sourcing
# Edge computing
# AI
# Scope
# scientific practice
# Azure
# community resources
# climate resilience
# AI skills
# housing
# Open Compute Project
# air pollution risk
# corporate responsibility
# sustainable agriculture
# veteran benefits
# political
# safety
# employee training
# data governance
# water loss
# graphics
# assistive technology
# embedded processor
# GHG
# shared value
# employee support
# market competitiveness
# genomics
# tracking prevention
# lab safety
# greener economy
# diagnosis
# girls
# talent retention
# supply chain responsibility
# server performance
# inclusive economy
# EMBB
# sponsorship
# industry dialogues
# sustainability practices
# smarter chemistry
# racism
# recycling
# sustainability policy
# advertising
# sustainability management
# container registry
# scientific computing
# AI challenges
# energy demand
# open-source
# disability accommodations
# customer use
# VAP
# non-hazardous waste
# learning
# impact
# plastic
# smartphones
# independent directors
# customer success
# digital skills training
# revenue
# SEC
# autonomous vehicles
# evaluations
# sections
# open standards
# exclusion
# supplier actions
# bonded labor
# water technology
# sustainable procurement
# market reach
# audit program
# Daisy
# principles
# recycled aluminum
# board
# biochar
# disability
# year
# modeling
# navigation
# supplier
# advocacy
# collaboration
# software
# VOC
# product sustainability
# devices
# priorities
# deforestation
# protein science
# supplier repayment
# assets
# index
# intellectual honesty
# supply chain assessments
# image recognition
# environmental certifications
# board of directors
# supplier sustainability
# recycled cobalt
# disadvantaged communities
# countries
# publicly listed
# water access
# carbon capture
# reporting date
# carbon emissions reduction
# global
# sensitivity analysis
# carbon price risk
# information systems
# solar performance
# manufacturer
# target
# emission types
# fee return
# actions
# land protection
# sustainable sourcing
# poverty
# negative impact
# investments
# digital platform
# reviewer credentials
# trust
# simulation testing
# regulatory compliance
# tool
# market trends
# carbon storage
# non-technical roles
# Apple Watch Mirroring
# data summary
# hackathon
# smart agriculture
# LGBT+ inclusion
# sustainable products
# advisories
# fuel economy
# stem education
# international relations
# verification
# emissions abatement
# brand
# supplier employees
# subsidies
# access to water
# data centers
# inspections
# veteran support
# carbon assessment
# project
# flax
# board composition
# ecosystem protection
# personal protective equipment
# visual computing
# internship
# CSR impact
# respect
# standards
# results
# labor initiative
# command center
# grievance hotline
# framework
# customer privacy
# flooding risk
# wireless
# mobile computing
# trade
# fishery industry
# geography
# scrap
# beneficiaries
# emissions reporting
# perfection
# Employee Giving
# workforce development
# alignment
# compensation
# water risk
# pollution reduction
# customer benefits
# sustainability community
# talent gap
# states
# sustainability goals
# law enforcement
# ecosystem performance
# zero waste
# product contribution
# components
# water scarcity
# data acquisition
# product use
# scope 3 emissions
# teamwork
# sustainability progress
# COVID-19 response
# governance structure
# mental health support
# employee safety
# REJI
# deadline
# recognition
# frontline health workers
# water stress
# water consumption
# contingent worker training
# sustainability innovation
# responsible minerals sourcing
# mineralization
# water sustainability
# transportation emissions
# regulatory
# employee volunteerism
# water.org
# mission statement
# wildlife conservation
# quality
# water crisis
# safety recognition
# share repurchases
# royalties
# family leave
# business travel
# employee rights
# digital readiness
# farming
# supplier standards
# remedy mechanism
# new hires
# communication
# diesel-free
# sustainability skills
# programming model
# population density
# volunteer support
# government collaboration
# land conservation
# renewable energy
# forced labor
# solidarity
# neodymium
# water supply
# Qualcomm Incorporated
# small business support
# supplier incentives
# AVOB
# electricity
# scope 1 emissions
# political action committee
# cycling
# GDP
# employee turnover
# safety report
# audit
# decarbonization
# downstream transportation
# wireless coverage
# AMD processors
# supply chain sustainability
# performance improvement
# GitHub
# associate degree
# mosquitoes
# fiscal year
# water risk management
# LGBTQ benefits
# interest
# wind
# supplier support
# carbon ambition
# business model
# wearable technology
# logistics
# youth empowerment
# material efficiency
# white paper
# carbon footprint
# carbon economy
# leased assets emissions
# lead director
# adaptation
# material consumption
# outdoor equity
# materiality
# construction waste
# ventilators
# natural resources
# value chain
# supplier performance
# management approach
# pipeline
# ISO 27000
# hotlines
# industry initiatives
# climate leadership
# patents
# energy management
# incorporation
# racial justice
# housing affordability
# life events support
# policy engagement
# performance metric
# industry engagement
# ethnic diversity
# desktops
# occupational health and safety
# incentives
# legal compliance
# geospatial workflows
# supplier list
# ESG Index
# donated technology
# ethical sourcing
# ESG opportunities
# OECD
# labeling
# workforce readiness
# manufacturing expansion
# lighting optimization
# performance evaluation
# sustainable finance
# perfluorinated compounds
# review
# response time
# sustainable fuels
# donation
# women in the workforce
# IPCC
# forestry
# veterans
# strategic planning
# privacy labels
# biodiversity
# values
# chemicals
# repair
# employee
# just transition
# encryption
# wood sourcing
# business continuity
# data-centric
# water innovation
# platform
# indirect heating
# UN
# internal mobility
# youth
# greenhouse gas
# long-term impact
# worker safety
# economic
# BREEAM certification
# North America
# landfill diversion
# analysis quality
# LCA datasets
# supply chain transparency
# employee base
# processing power
# organization
# environmental sustainability
# health checks
# Live Captions
# cultural heritage
# headquarters
# carbon disclosure
# women in tech
# hardware
# vaccines
# CDP
# workforce planning
# reuse
# reporting scope
# environmental impact
# assessment
# investment
# solutions
# goal achievement
# new construction
# disaster response
# inclusion index
# business practices
# governance
# occupational
# ghg
# mapping
# smart home
# data platform
# global connectivity
# materials
# employee retention
# landscaping
# device efficiency
# contact information
# supplier reporting
# e-sports
# water security
# phthalates
# thinkabit lab
# export
# board diversity
# health
# sustainable development goals
# professional events
# employee benefits
# latina empowerment
# disclosure
# women in leadership
# women empowerment
# safety management
# ghg emissions
# employee satisfaction
# bereavement leave
# other
# health and safety standards
# office
# Ukraine
# distribution
# sasb
# sustainability solutions
# renewable fuel
# MGM
# CSR strategy
# workforce diversity
# workforce
# competitiveness
# proxy statement
# savings
# server density
# investment principles
# data visualization
# environmental compliance
# 4G
# SharePoint
# US government
# employee recognition
# female entrepreneur
# green skills
# benefits
# customers
# message
# workplace policies
# our people
# water conservation
# emissions increase
# AI research
# operations
# Guizhou Province of China
# energy access
# critical suppliers
# climate modeling
# RBA
# success
# employee stock ownership
# performance-based
# human rights policy
# Paris Agreement
# supply capacity
# sustainable innovation
# volunteer work
# freedom of expression
# carbon
# ecosystem restoration
# pdf file size
# employee engagement
# cross-functional collaboration
# product security
# training hours
# contamination
# crisis management
# subsidiaries
# hazardous substance elimination
# crisis response
# agriculture
# days away case rate
# India
# business growth
# workplace safety
# retirement
# business fleet
# efficiency
# targets
# environmental leadership
# Planetary Computer
# RISE global challenge
# power efficiency
# green energy
# non-conformances
# quality control
# document review
# waste recycling
# volunteer hours
# grants
# injury rate
# financial impact
# industry
# human trafficking
# Microsoft
# climate action
# capital equipment
# Dalian factory
# remote work
# continuous improvement
# excellence
# board members
# authentication
# power reduction
# none
# career development
# pandemic response
# talent development
# packaging reduction
# planetary computer
# transportation
# smart metering
# reporting criteria
# strategic focus areas
# grant program
# GPU accelerators
# water withdrawals
# education access
# audits
# trade compliance
# physics
# minority-owned businesses
# customer loyalty
# director nominees
# LEED
# criminal justice reform
# alliance
# school
# violations
# risks and uncertainties
# reporting framework
# governmental relations
# performance
# surveys
# production lines
# mobile technology
# accreditation
# industry-specific issues
# plastic elimination goal
# scope 2
# U.S.
# major customers
# NAND memory
# JROTC-CS
# business success
# supporting team members
# GDPR
# employee welfare
# breakthrough
# food bank
# business continuity management
# markets
# supplier disclosure
# environmental management
# impact assessment
# e-waste management
# video conferencing
# customer care
# life cycle assessment
# circuit boards
# mentoring
# regulation
# data quality
# guidance
# forecasting
# health crises
# remediation
# scale
# competition
# economic equality
# composting
# scalability
# transistor
# human capital management
# worker rights
# policymakers
# employee onboarding
# social impact
# pay transparency
# waste disposal
# protection
# GPU
# mission
# professional development
# customer
# ink
# students
# STEM education
# future-proof
# cloud infrastructure
# data protection
# pay equity
# foreign
# breakthroughs
# rounding
# PUE
# mining
# range
# wildfires
# ISO 14021
# quality improvement
# datacenter
# inclusion
# consultation
# product
# environmental report
# governmental compliance
# collective bargaining
# supplier compliance
# LinkedIn
# design
# electrification
# climate reporting
# SK hynix
# server efficiency
# IT infrastructure
# data sharing
# durability
# GTC DC
# energy cost
# reputation
# employee development
# underserved communities
# community support
# Earth science data
# GPU acceleration
# sign language
# ecosystems
# skill designations
# public safety
# human resources
# testing
# ecodesign
# license to operate
# environmental initiatives
# AI optimization
# distributed energy
# sustainability report
# focus areas
# assessment approach
# cooling
# board approval
# sustainability incentives
# lobbying
# management framework
# security optimization
# legal team
# conflict of interest
# vehicle gasoline
# supplier screening
# recognition program
# rural areas
# platform strategy
# plant species
# responsible labor recruitment
# life cycle phases
# survey
# provider
# product end-of-life emissions
# Intel Foundation
# compensation clawback
# trade issues
# determination
# awards and recognition
# forest conservation
# conservation
# water discharge
# private sector
# supplier requirements
# market demand
# satellite images
# representation
# buyback
# promotion parity
# energy transition
# shareholders
# pages
# silicon technology
# smart cities
# carbon benefits
# GHG emissions
# supercomputers
# methodology
# investor feedback
# marketing
# substances
# radiology
# cyclones
# elow
# climate
# company mission
# classroom training
# Teams
# Indonesia
# toolkit
# costs
# digital governance
# feedback and performance management
# chemical safety
# sustainability training
# LGBTQ+ support
# social media
# visual effects
# circular economy
# investment strategy
# portfolio management
# telework
# non-renewable electricity
# political support
# lessons learned
# product safety
# reporting process
# business risks and opportunities
# digital technologies
# agility
# information quality
# data-driven decision making
# recyclable products
# sustainability reporting
# milestone
# coalition
# patient impact
# ESG reporting
# product shipments
# wildlife corridor
# temporary
# industry leadership
# caregiver support
# manufacturing suppliers
# integrity
# industry initiative
# ods
# batteries
# FCA
# inclusivity
# supplier quality
# user registration
# environmental policy
# natural gas
# telecommuting
# emission reduction performance
# app development
# ozone depletion
# international outreach
# concrete mix
# data analysis
# waste emissions
# product energy efficiency
# user data
# retail stores
# global culture
# national security
# water disclosure
# sustainable consumption
# climate scenario analysis
# water stewardship
# sublets
# age diversity
# global impact
# worker interviews
# customer protection
# supplier engagement
# laboratory safety
# supplier assessment
# performance optimization
# work-life balance
# fluid dynamics
# LGBTQI+
# assurance
# standard
# occupational health
# pay parity
# renewable energy procurement
# company name
# CSR reporting
# underserved areas
# incident rate
# particulate matter
# material risks
# tcfd
# non-discrimination
# unionization
# commitment
# customer engagement
# health education
# voting practices
# OneDrive
# green growth
# green building
# inclusive design
# camera technology
# morbidity rates
# product ecology
# power purchase agreements
# final assembly supplier sites
# MND
# company
# suppliers
# score
# reporting period
# endnotes
# employee wellness
# certification
# tax payments
# guidelines
# remote
# location-based
# energy policy
# accuracy
# NGO
# contact point
# educator
# cobalt
# carbon credits
# community outreach
# traffic management
# penetration tests
# goals
# data-driven
# anti-counterfeit
# energy-efficiency
# reporting standard
# data access
# automation
# village
# Israel
# societal impact
# diverse talent
# capital goods
# UN SDGs
# responsiveness
# electronics
# lake restoration
# women's empowerment
# NIST
# emission factors
# business segments
# TCFD
# languages
# CFO
# market-based
# business conduct
# international cooperation
# R&D center
# LEED Gold
# workforce demographics
# carbon neutrality
# air pollution
# carbon neutral computing
# ESG report
# recyclability
# audits and inspections
# electronic waste
# supply chain management
# technical women
# business performance
# Code of Business Conduct
# performance management
# energy research
# square footage
# voluntary program
# training
# improvement
# disclosures
# plastic reduction
# youth engagement
# 2019
# Illinois
# GRI
# company description
# workplace experiences
# warming scenario
# grid modernization
# education
# location
# support
# girls in tech
# security personnel
# technical diversity
# BVI
# third-party assurance
# waste diversion goal
# reports
# training and development
# THRIVE program
# inclusive growth
# scientific principles
# safety certifications
# issue identification
# furniture reuse
# community investment
# next steps
# work councils
# applications
# risk oversight
# browser
# vulnerability management
# history
# electricity consumption
# time period
# chemical management
# schools
# overview
# diversion rate
# parental leave
# worker voice
# AMD suppliers
# habitat connectivity
# 3D printing
# Chyulu Hills project
# company culture
# screening
# reporting practices
# legal profession
# carbon price
# restoration
# issues
# claw back policy
# succession planning
# retail location
# total waste
# initiative
# GHG emissions reduction target
# 2025
# inclusive language
# stakeholder capitalism
# promotion
# management diversity
# Middle East
# cooling solutions
# podcast
# consumer protection
# location-based method
# mangrove conservation
# corrective action plan
# industry standards
# gri
# executive diversity
# responsible AI
# developer support
# service
# safer materials
# AI inference
# community projects
# 5G development
# innovation
# community engagement
# energy usage
# policy advocacy
# customer support
# construction waste reduction
# Belize
# climate goals
# product testing
# sustainability goal
# unconscious bias
# awareness
# beneficiary
# waste export
# franchises
# career
# about
# product longevity
# Ireland
# giving
# water collaboration
# product design
# Restore Fund
# reuse rate
# Asia
# rack count
# carbon transformation
# upgrade
# inaction
# 8D methodology
# responsibility
# part-time
# decision-making
# occupational safety
# family safety
# iPhone
# conferences
# remote learning
# Door Detection
# nitrogen oxides
# mobile processors
# high-risk areas
# embedded products
# tier 1
# solar
# roadmap
# incident reporting
# whistle-blower protection
# low-carbon
# social innovation
# volunteerism
# climate disclosure
# zero waste goal
# 6G
# social entrepreneurship
# carbon emissions
# leadership development
# emission intensity
# AI performance
# GHG reduction goal
# talent acquisition
# reportable segment
# design that empowers
# Asia Pacific
# financial
# product lifetime
# app
# matching gift programs
# supply chain operations
# GPUs
# industry organizations
# business integration
# offshore wind energy
# financial measures
# online training
# personal development
# racial pay gap
# out-of-school-time learning
# anti-racism
# urbanization
# corporate culture
# legal proceedings
# travel emissions
# research team
# safety performance
# teacher support
# programs
# boundary
# Airband
# united states
# water risk assessment
# climate roadmap
# risks
# fishermen
# youth development
# data availability
# product responsibility
# challenge
# sustainability platform
# space efficiency
# conflict minerals
# power optimization
# injury reporting
# accounting
# AI talent development
# labor practices
# financing sustainability
# government funding
# humanitarian aid
# import
# APAC
# sustainable product design
# letter
# 2020
# GreenScreen
# affordable housing
# carbon reduction
# Earth systems
# traffic efficiency
# fabless
# stakeholder
# cloud-server platform
# adaptability
# tools
# corporate fiber usage
# digital impact
# programme
# stakeholders
# Europe
# parts
# external assurance
# rural communities
# RBA audit
# scientific research
# review process
# monitoring
# sustainable materials
# contract employees
# end-of-life
# phishing
# youth programs
# business strategy
# qtl
# climate solutions
# internal audit
# industrial computers
# dust and water resistance
# legal form
# health violations
# GRI Standards
# social performance indicators
# fire safety
# supplier training
# footprint
# corporate governance
# inference
# building decarbonization
# recycled materials
# AI education
# fossil fuels
# teachers
# carbon neutral
# direct emissions
# threat intelligence
# energy conservation
# fines and penalties
# smart lighting
# laptop
# environmental responsibility
# disclaimer
# visitor badges
# electronics industries
# customer base
# international norms
# sustainable infrastructure
# cloud solutions
# investors
# company values
# product lifecycle emissions
# worker treatment
# dataset
# opportunities
# culture
# supply chain
# charitable giving
# protected land
# climate fund
# environmental education
# material topic
# baseline
# executive compensation
# stock ownership
# material safety standards
# UNICEF
# goal
# resource library
# plastic waste
# update
# environmental strategy
# Board involvement
# product roadmap
# AI technology
# report
# health and safety
# processor
# United States
# material reduction
# energy source
# technology access
# digital skills
# core values
# COVID-19
# resources
# Thailand
# global presence
# sales
# US Capitol
# senior management
# COVID-19 support
# Americas
# supply chain audits
# government technologies
# mobility
# people
# developing countries
# recycled waste
# employee giving
# environmental survey
# Qualcomm
# covid-19 response
# hazardous materials
# mitre
# retirement benefits
# nist
# outdoor maintenance
# brominated flame retardants
# job satisfaction
# scenario analysis
# ICT
# R&D investment
# data transparency
# space exploration
# machine to machine communications
# housing accessibility
# commute
# philanthropy
# broadband connectivity
# supplier data
# product lifecycle
# anti-competitive behavior
# progress
# engineering
# award
# AI platform
# developer community
# employee well-being
# product specific
# headcount
# community strengthening
# purchase
# whistleblower protection
# real estate
# supply chain resilience
# fines
# technology leadership
# energy mix
# diversity and inclusion training
# environmental violations
# sustainable building
# leadership diversity
# IP portfolio
# sanitation
# processor design
# executive leadership
# on-demand learning
# fiber use
# off-grid energy
# server reduction
# material recovery
# construction
# awards
# safety standard
# PVC
# water quality
# accountability
# industry collaboration
# incident response
# electric vehicles
# divestiture
# diesel
# fuel
# sourcing
# diesel fuel
# network infrastructure
# risk management
# reliance
# government partnerships
# green power
# emissions reduction
# sustainable transportation
# transition
# pandemic leadership
# answers
# funding
# retaliation
# nonprofit
# river conservation
# emoji
# photobooks
# energy
# cooling technology
# online safety
# environmental policies
# product repair
# integration
# commercialization
# indirect energy consumption
# ergonomics program
# material selection
# company initiatives
# smart campus
# inclusive workplace
# shareholder engagement
# fine
# data security
# Smart Places
# board governance
# employee participation
# connectivity
# JROTC
# Texas
# cigarette butts
# entrepreneurship
# medical support
# activism
# stockholders
# carbon aware software
# performance tracking
# technology
# board refreshment
# product takeback
# water recycling
# publication
# diversity and inclusion
# expenses
# Sentinel-2
# coding
# lifecycle assessment
# renewable energy certificates
# Mobileye
# whistleblower
# edge computing
# materials availability
# investor relations
# employee distribution
# open source
# sales offices
# ILO
# contractors
# ai platform
# facility management
# wellbeing
# construction waste diversion goal
# GHG reduction
# 2°C
# carbon monoxide
# management
# retail experience
# CSR awards
# waste
# sustainability awareness
# EHS management
# safety record
# WiSci
# supercomputer
# water footprint
# GHG emissions reduction
# recycled content
# coral reef
# workplace action plans
# talent management
# policy
# electricity savings
# time frame
# blood donation
# business unit
# reporting standards
# Impact Observatory
# sustainable practices
# influence
# annual report
# reverse logistics
# citizen science
# equal opportunity
# leadership training
# chemistry
# 5G
# compatibility
# health risks
# DNA sequencing
# esg
# defect detection
# climate entrepreneurs
# venture capital
# investor engagement
# data science
# remanufacturing
# business
# Guatemala
# supply chain emissions
# conflict-affected areas
# site count
# clean energy
# ai
# end-of-life treatment
# broadband access
# server capacity
# Earth observation
# performance review
# computer vision
# STEAM
# material disclosure
# solar energy
# data privacy
# datacenters
# stock exchange
# AI conference
# bug bounty
# HPC
# fiber
# fluctuations
# data improvement
# data center
# academic research
# regulations
# Germany
# LGBTQ+ rights
# frontline workers
# equal employment opportunity
# commit
# facial recognition
# water
# Future Skills
# outreach
# invention
# sustainable future
# well-being
# jet fuel
# mercury
# waste reduction
# quote
# diversity
# employee empowerment
# community
# carbon accounting
# waste tracking
# carbon footprint accuracy
# device usage
# quality management
# carpooling
# supplier code of conduct
# fiber footprint
# computer graphics
# fitness
# empowerment
# digital divide
# responsible investment
# clawback policy
# self-awareness
# production
# EMEA
# algorithmic risk
# biogas
# intensity
# sustainability commitment
# best practices
# founding year
# employees
# robotics
# nature-based solutions
# first.org
# solar panel manufacturing
# lighting
# services
# waste diversion
# process water withdrawals
# market
# workplace communication
# assurance methodology
# notices of violations
# survey participation
# food waste
# gasoline
# caring for customers
# trademarks
# metric description
# matching gifts
# Dynamics 365
# households
# work culture
# conflict-free
# EU
# certifications
# circular design
# energy use
# Tim Cook
# education equity
# community relations
# cancer
# inspiration
# PPE
# rights
# flexibility
# energy savings
# performance-based pay
# sustainability resources
# materiality matrix
# ranking
# Hapinoy program
# sustainable fashion
# purpose
# servers
# digital safety
# local giving
# internet access
# workload scheduling
# sensors
# mentorship
# compensation strategy
# new offices
# technology skills
# low carbon innovation
# international
# satellite imagery
# wellness program
# waste to landfill
# products
# ocean information
# strategy
# LCA studies
# TCO
# CEO
# audit process
# recycling technology
# affirmative action
# ecosystem health
# safety violations
# code of conduct
# performance measurement
# evaluation
# RSS
# ireland
# energy intensity
# emerging technologies
# developer conference
# IDM
# board leadership
# learnings
# poverty alleviation
# report accessibility
# founding
# workplace discrimination
# ESG disclosure
# turnover
# beach cleaning
# Malaysia
# employee diversity
# commuting emissions
# sustainable growth
# employee choice
# internships
# data standards
# propane
# oversight
# 5G adoption
# sustainable aviation fuel
# water sources
# conflict zones
# system
# software engineering
# IT asset disposition
# content removal
# foundry partners
# performance-based compensation
# datacenter efficiency
# volunteers
# international aid
# education policy
# ESG
# GTCs
# carbon removal
# education and employment
# sustainability partnerships
# wireless reach
# forward-looking statements
# server count
# about the report
# sanitation services
# volunteer
# online learning
# legislation
# capital goods emissions
# hazard
# divestment
# social
# employee discounts
# RECs
# financial commitment
# qsi
# plastic waste reduction
# employee commuting
# cultural
# long-term thinking
# precautionary principle
# recruitment fees
# embedded carbon
# total learners
# skill development
# wireless connectivity
# signage
# injury types
# generational diversity
# quality of care
# 3G
# app downloads
# diverse suppliers
# contract theory
# inventory
# foreign currency
# supplier stewardship
# corporate social responsibility
# employee demographics
# rare earth elements
# investor return
# environmental assessment
# automated vehicles
# data analytics
# climate research
# data center efficiency
# sustainable packaging
# minerals
# appendix
# power consumption
# ethical leadership
# climate-related
# timeline
# reclamation
# government support
# emissions
# feedback
# green jobs
# high-performance computing
# refurbishment
# United Nations
# inequality
# age
# user consent
# cloud hardware
# artisanal and small-scale mining
# software upgrades
# climate governance
# business operations
# awareness program
# hydro power
# management quality
# non-renewable energy
# waste heat
# open data
# hazardous waste management
# material assessment
# sustainability data
# financing
# issues assessment
# mental health
# leadership roles
# employee growth
# inventory boundary
# Mexico
# relations
# fatalities
# anti-corruption
# gdpr
# safety culture
# inclusive procurement
# autonomous driving
# emergency preparedness
# relationship
# autism
# policy development
# collective agreements
# due diligence
# PPAs
# gender categories
# circular economy partnerships
# takeback
# events
# report content
# initiatives
# number of learners
# volunteer training
# tin
# noncompliance
# fundraising
# women
# LEED Silver
# china
# cold chain
# emission reduction
# expertise
# data collection
# military support
# multicultural women
# network expansion
# inclusive leadership
# fuel emissions
# power performance
# economic development
# OSHA recordable rate
# water positive
# privacy
# water efficiency
# contract
# responsible marketing practices
# sulfuric acid
# waste monitoring
# data center optimization
# SASB
# technical roles
# carbon monitoring
# spending
# risk assessment
# wireless technology
# health and wellness
# Africa
# mitigation
# fisheries
# licensing
# land cover
# digital civility
# employee networks
# IoT
# performance metrics
# environmental goals
# version
# gaming
# emissions offsetting
# tax credit
# ai training
# employee resources
# leadership councils
# employability
# artificial intelligence
# ethical conduct
# scope 3
# response
# stakeholder engagement
# hydrate formation
# sustainability
# employee health and safety
# disaster recovery
# workplace culture
# low-carbon materials
# capitalization
# NGOs
# supply chain safety
# gender
# sustainable design
# modern slavery
# employee incentives
# sensor data
# crowdsourcing
# scope 1
# landfill waste
# supplier accountability
# AMD operations
# risk
# product quality
# discrimination
# supplier risk
# compliance
# LGBTQ support
# app economy
# greenhouse gas emissions
# veteran inclusion
# assurance team
# success story
# reporting
# mobile app
# stakeholder expectations
# south korea
# AI for Good
# policy update
# labor market
# rural development
# income increase
# social and environmental compliance
# thought leadership
# cloud
# community service
# inclusive environment
# IT asset management
# temperature risk
# bias
# e-learning
# supplier partnerships
# board attendance
# travel reduction
# smart building
# value creation
# product impact
# privacy features
# farmers
# differentiation
# aviation
# policy plan
# thrive
# distillate fuel oil
# celebrations
# interview process
# HR
# hiring
# social justice
# corporate citizenship
# gender diversity
# server infrastructure
# recycled devices
# product portfolio
# software updates
# recycled tin
# joint ventures
# freedom of association
# workplace wellness
# maps
# scope 2 emissions
# land footprint
# disability representation
# acquisition
# Big Data
# labor standards
# data accessibility
# social equity
# board committees
# educator development
# transformation
# carbon offsets
# water resilience
# survey response rate
# facilities
# customer requirements
# manufacturing waste
# recycled fiber
# parking
# executive stock ownership
# low-income households
# talent strategy
# family benefits
# BCM
# committee
# government
# human capital
# testimonial
# supply chain risk
# digital technology
# computing power
# security
# 10-K
# responsible business practices
# capacity-building
# computer chip
# networking
# knowledge sharing
# emission reduction target
# materials science
# digital privacy
# reporting history
# sustainable aviation
# ISO
# foundries
# analytics
# data
# net zero
# assessments
# technical positions
# renewable power
# sustainability award
# Colombia
# spares program
# product misuse
# water use
# business interruption
# promotions
# participation
# objectivity
# cooling optimization
# forest carbon
# wildlife
# social welfare
# C-V2X
# UNGPs
# Esri
# global network
# pandemic leadership team
# csr
# gender pay gap
# reporting promotion
# forestation
# AP computer science
# sustainable fishing
# healthcare
# conference
# environmental workgroup
# sustainability education
# acquisitions
# disaster relief
# skills development
# circularity
# community empowerment
# water treatment
# artisanal mining
# reduction target
# digitization
# executives
# frameworks
# customer experience
# EMS
# esg reporting
# economic performance
# management assertion
# startup
# water data
# systems change
# manufacturing facilities
# future outlook
# computing
# customer service
# Taiwan
# academic institutions
# charitable donations
# mobile wireless communications
# aviation emissions
# product LCA
# cookies
# R&D
# systemic racism
# water management
# social responsibility
# SDGs
# water savings
# charity
# director compensation
# transistors
# disabilities
# volunteering
# steam
# technology initiative
# corrective action
# employee feedback
# EPEAT
# VCS
# demand
# TEALS
# NVLink
# industry comparison
# virgin fiber
# medical technology
# supplier employee survey
# community solar
# community benefits
# water system
# political contributions
# medical devices
# retail
# customer story
# product reliability
# R&D efficiency
# Wi-Fi
# revisit time
# report assurance
# fertilizer
# environmental protection
# LCA
# future
# tree planting
# non-technical positions
# simulation
# product labeling
# humanitarian
# ethical business practices
# land use
# emergency response
# sustainable travel
# supplier employee engagement
# machine learning
# self-assessment
# RISE
# corporate structure
# data collaboration
# tri-band technology
# URM representation
# art
# market projection
# accelerated computing
# trends
# skills-based volunteering
# employee type
# microprocessors
# skills gap
# racial equity
# ai performance
# partnership
# ratings
# arts
# green
# infrastructure
# data integration
# human rights
# information
# imagery
# atmospheric rivers
# US
# cloud computing
# environmental monitoring
# climate policy
# compliance mechanisms
# users
# jobs
# acronyms
# perseverance
# product brand
# employee count
# datacenter sustainability
# ownership
# cost savings
# economic sustainability
# climate investment
# supplier evaluation
# gender equality
# inclusive sourcing
# forward contracts
# reporting options
# climate platform
# corporate responsibility priorities
# reduction
# carbon negative
# financial metrics
# semiconductor
# scholarships
# hazardous substances
# metals
# business benefits
# job descriptions
# recyclable packaging
# industry transformation
# vision
# third-party verification
# memberships
# democracy
# backup power
# sustainable landscaping
# pandemic alliance
# investor satisfaction
# productivity
# ip
# customer data
# workplace surveys
# wildlife protection
# AI for Earth
# ethics and compliance
# response to COVID-19
# forest restoration
# sales operations
# carbon pricing
# Title 1
# acceleration
# wastewater
# policies
# Surface devices
# civil rights
# Moovit
# semiconductor emissions
# worker feedback
# skills
# all-electric kitchens
# research and development
# resource efficiency
# environmental standards
# pollutant diffusion
# environment
# device repairability
# regional emissions
# reporting year
# investigation
# financial inclusion
# intellectual property
# reporting changes
# sustainable facilities
# knowledge-sharing
# project portfolio
# bipartisan
# political expenditures
# weather forecasting
# labor rights
# water inventory
# dignity
# SF6
# responsible minerals trade
# customer education
# workers
# corporate offices
# sustainability initiatives
# Life Cycle Assessments
# global effort
# financial performance
# gold
# adoption
# startups
# patent portfolio
# smart energy
# product development
# micro-loans
# fairness
# emergency services
# sustainability software
# consumer devices
# media partnership
# capacity building
# biodiversity informatics
# solar power
# refrigerants
# scholarship
# energy consumption
# creativity
# cybersecurity
# benchmarking
# sustainable forestry
# environmental assessments
# women-owned businesses
# distributed computing
# inclusive hiring
# Memoji
# digital tools
# project type
# coverage rates
# stem
# urban roads
# dividends
# digitalization
# environmental stewardship
# talent
# legal
# development
# economic impact
# translation
# growth
# experience
# climate innovation
# assembly
# atmosphere simulation
# cost
# lower risk suppliers
# alliance for global inclusion
# accessibility
# coaching
# reporting mechanisms
# digital twin
# qct
# district heat
# board evaluation
# water metrics
# AI supercomputers
# AI evangelism
# carbon-free energy
# modem
# grid electricity
# supplier responsibility
# closed-loop supply chain
# operating costs
# industry associations
# public health
# digital literacy
# antitrust
# immigration
# future thinking
# rewards
# interconnect technology
# international trade
# China
# tracking transparency
# injury reduction
# recyclable materials
# industries
# CCB
# hydrogen fuel cells
# workers compensation
# capacity
# digital transformation
# public policy
# economic growth
# data accuracy
# fundamental rights
# crops
# BSR
# introduction
# lifelong learning
# effluents
# country-by-country
# road safety
# talent pipeline
# teacher training
# food security
# water reduction
# Power BI
# power distribution
# standards development
# committees
# standards and regulations
# warehouse automation
# computer chips
# returns
# job creation
# measurements
# employment
# CUDA
# financial disclosure
# medical imaging
# fabrication
# harassment
# benchmark
# water replenishment
# injuries
# worker satisfaction
# digital inclusion
# AI training
# HPE
# availability
# country
# customer feedback
# medical research
# language preservation
# safety culture guide
# responsible recruitment
# renewable materials
# finance
# time off
# workforce management
# disassembly
# governance communities
# Ceres
# expenditures
# accelerator
# procurement
# third-party audits
# ocean plastic
# biodiversity conservation
# recruitment
# international development
# employee behavior
# race equality
# TAI
# hero
# sustainable manufacturing
# office closure
# materiality assessment
# recycled material
# attack
# self-driving cars
# growth mindset
# water resistance
# employee referrals
# independence
# recycling rate
# climate change
# security controls
# networking efficiency
# efficient buildings
# reduction achievement
# Washington
# metrics
# HBCUs
# sustainability metrics
# processes
# reporting frameworks
# compulsory labor
# report scope
# recyclable
# program name
# climate finance
# legal action
# resource management
# pandemic support
# membership
# research projects
# museum
# Black-owned businesses
# disposal
# manufacturing
# AI for Health
# app store
# AI software
# water withdrawal
# nonprofits
# embedding respect
# worker welfare
# water restoration
# government relations
# retention
# incident
# corruption
# NSF
# review method
# packaging
# carbon offset
# methodologies
# ethical hiring
# Indigenous communities
# battery life
# LEED Platinum
# capital strategy
# business excellence
# resilience
# deployment
# inclusion and diversity
# wind power
# formal model
# computational cost
# program impact
# operational resilience
# ethical governance
# employee experience
# campus fleet
# recycled paper
# information access
# Intel Capital
# urban development
# iRECs
# science
# taxation
# career growth
# embodied carbon
# data-driven decision-making
# environmental health and safety
# cement
# leadership
# vulnerable populations
# Scope 1 emissions
# materiality assessments
# corrective actions
# locations
# small business
# critical materials
# learning platform
# demographics
# feedback mechanisms
# EHS
# life sciences
# process
# societal impacts
# IP protection
# supplier audits
# global reach
# senior leadership
# renewable diesel
# black lives matter
# hospitals
# approach
# transparency
# coastal changes
# donations
# LEED certification
# AI for Youth
# grant
# equity
# AI governance
# comparison
# employee unionization
# laptops
# currency
# technology for good
# solvents
# carbon sequestration
# technology education
# platinum certified
# human factor
# employee health
# feedback channels
# hazardous waste
# water usage
# economic value
# shipping
# responsible business
# digital accessibility
# geopolitical
# employee resource group
# award program
# AI systems
# capability-building
# employee conduct
# ergonomics
# learning and development
# reliability
# aluminum
# interviews
# campus sustainability

# %%
pipeline = [
    {
        '$match': {
            'metric': True,
            'topic': 'G'
        }
    },
    {"$unwind": "$tags"},
    {"$group": {"_id": "$tags", "count": {"$sum": 1}}},
    # {"$group": {"_id": None, "uniqueValues": {"$push": "$_id"}}},  # Collects all unique values into a single array
    # {"$project": {"_id": 0, "uniqueValues": 1}}  # Optional: Formats the output to only show the array of unique values
    {"$sort": {"count": -1}}  # Optional: sorts the results by count in descending order
]

unique_values = client.vectordb.company_key_data.aggregate(pipeline)

# Assuming you want to print the array of unique values
for value in unique_values:
    print(value)
# Out:
# {'_id': 'compliance', 'count': 31}
# {'_id': 'supply chain', 'count': 26}
# {'_id': 'supplier', 'count': 24}
# {'_id': 'training', 'count': 20}
# {'_id': 'risk management', 'count': 20}
# {'_id': 'diversity', 'count': 14}
# {'_id': 'partnerships', 'count': 13}
# {'_id': 'governance', 'count': 13}
# {'_id': 'sustainability', 'count': 13}
# {'_id': 'audit', 'count': 12}
# {'_id': 'cybersecurity', 'count': 11}
# {'_id': 'investment', 'count': 11}
# {'_id': 'philanthropy', 'count': 11}
# {'_id': 'financial performance', 'count': 10}
# {'_id': 'innovation', 'count': 9}
# {'_id': 'ethics', 'count': 8}
# {'_id': 'board of directors', 'count': 8}
# {'_id': 'security', 'count': 8}
# {'_id': 'employee engagement', 'count': 6}
# {'_id': 'climate change', 'count': 6}
# {'_id': 'board diversity', 'count': 6}
# {'_id': 'performance', 'count': 6}
# {'_id': 'finance', 'count': 6}
# {'_id': 'employee development', 'count': 5}
# {'_id': 'modern slavery', 'count': 5}
# {'_id': 'privacy', 'count': 5}
# {'_id': 'leadership', 'count': 5}
# {'_id': 'award', 'count': 4}
# {'_id': 'inspections', 'count': 4}
# {'_id': 'risk assessment', 'count': 4}
# {'_id': 'inclusion', 'count': 3}
# {'_id': 'policy', 'count': 3}
# {'_id': 'experience', 'count': 3}
# {'_id': 'diversity and inclusion', 'count': 3}
# {'_id': 'CSR', 'count': 3}
# {'_id': 'R&D', 'count': 3}
# {'_id': 'board attendance', 'count': 3}
# {'_id': 'safety recognition', 'count': 3}
# {'_id': 'research and development', 'count': 3}
# {'_id': 'supply chain transparency', 'count': 3}
# {'_id': 'independent directors', 'count': 3}
# {'_id': 'reporting', 'count': 3}
# {'_id': 'donation', 'count': 3}
# {'_id': 'stakeholder engagement', 'count': 3}
# {'_id': 'human rights', 'count': 3}
# {'_id': 'customer protection', 'count': 3}
# {'_id': 'URM representation', 'count': 2}
# {'_id': 'investments', 'count': 2}
# {'_id': 'research', 'count': 2}
# {'_id': 'BCM', 'count': 2}
# {'_id': 'computing power', 'count': 2}
# {'_id': 'financing', 'count': 2}
# {'_id': 'disclosure', 'count': 2}
# {'_id': 'COVID-19', 'count': 2}
# {'_id': 'global', 'count': 2}
# {'_id': 'dividends', 'count': 2}
# {'_id': 'supply chain audits', 'count': 2}
# {'_id': 'climate fund', 'count': 2}
# {'_id': 'gender diversity', 'count': 2}
# {'_id': 'renewable energy', 'count': 2}
# {'_id': 'carbon emissions', 'count': 2}
# {'_id': 'corrective action', 'count': 2}
# {'_id': 'entrepreneurship', 'count': 2}
# {'_id': 'supercomputers', 'count': 2}
# {'_id': 'audits', 'count': 2}
# {'_id': 'computing', 'count': 2}
# {'_id': 'assurance team', 'count': 2}
# {'_id': 'transparency', 'count': 2}
# {'_id': 'financial disclosure', 'count': 2}
# {'_id': 'pandemic response', 'count': 2}
# {'_id': 'reporting criteria', 'count': 2}
# {'_id': 'certification', 'count': 2}
# {'_id': 'gender', 'count': 2}
# {'_id': 'crisis management', 'count': 2}
# {'_id': 'standards', 'count': 2}
# {'_id': 'responsible sourcing', 'count': 2}
# {'_id': 'data privacy', 'count': 2}
# {'_id': 'affordable housing', 'count': 2}
# {'_id': 'AI', 'count': 2}
# {'_id': 'workplace safety', 'count': 2}
# {'_id': 'Planetary Computer', 'count': 2}
# {'_id': 'lobbying', 'count': 2}
# {'_id': 'safety', 'count': 2}
# {'_id': 'employee training', 'count': 2}
# {'_id': 'supplier assessment', 'count': 2}
# {'_id': 'taxation', 'count': 2}
# {'_id': 'reputation', 'count': 2}
# {'_id': 'technical diversity', 'count': 1}
# {'_id': 'reporting standards', 'count': 1}
# {'_id': 'pay equity', 'count': 1}
# {'_id': 'workforce', 'count': 1}
# {'_id': 'accessibility', 'count': 1}
# {'_id': 'engagement', 'count': 1}
# {'_id': 'employee recognition', 'count': 1}
# {'_id': 'ai performance', 'count': 1}
# {'_id': 'partnership', 'count': 1}
# {'_id': 'capital strategy', 'count': 1}
# {'_id': 'employee benefits', 'count': 1}
# {'_id': 'internet access', 'count': 1}
# {'_id': 'report', 'count': 1}
# {'_id': 'GHG reduction', 'count': 1}
# {'_id': 'acquisition', 'count': 1}
# {'_id': 'global presence', 'count': 1}
# {'_id': 'safety culture', 'count': 1}
# {'_id': 'anti-corruption', 'count': 1}
# {'_id': 'emergency response', 'count': 1}
# {'_id': 'sustainable solutions', 'count': 1}
# {'_id': 'wellness program', 'count': 1}
# {'_id': 'manufacturing', 'count': 1}
# {'_id': 'education', 'count': 1}
# {'_id': 'security personnel', 'count': 1}
# {'_id': 'climate innovation', 'count': 1}
# {'_id': 'translation', 'count': 1}
# {'_id': 'startups', 'count': 1}
# {'_id': 'supplier audit', 'count': 1}
# {'_id': 'legal', 'count': 1}
# {'_id': 'product safety', 'count': 1}
# {'_id': 'corporate citizenship', 'count': 1}
# {'_id': 'expenses', 'count': 1}
# {'_id': 'digital technologies', 'count': 1}
# {'_id': 'health crises', 'count': 1}
# {'_id': 'materiality assessment', 'count': 1}
# {'_id': 'Mobileye', 'count': 1}
# {'_id': 'share repurchase', 'count': 1}
# {'_id': 'investor relations', 'count': 1}
# {'_id': 'independence', 'count': 1}
# {'_id': 'social entrepreneurship', 'count': 1}
# {'_id': 'product portfolio', 'count': 1}
# {'_id': 'voluntary program', 'count': 1}
# {'_id': 'academic institutions', 'count': 1}
# {'_id': 'manufacturing sites', 'count': 1}
# {'_id': 'investor return', 'count': 1}
# {'_id': 'performance management', 'count': 1}
# {'_id': 'intellectual property', 'count': 1}
# {'_id': 'energy-efficiency', 'count': 1}
# {'_id': 'responsibility', 'count': 1}
# {'_id': 'water management', 'count': 1}
# {'_id': 'labor rights', 'count': 1}
# {'_id': 'share repurchases', 'count': 1}
# {'_id': 'expenditures', 'count': 1}
# {'_id': 'GDPR', 'count': 1}
# {'_id': 'advocacy', 'count': 1}
# {'_id': 'GPU accelerators', 'count': 1}
# {'_id': 'collaboration', 'count': 1}
# {'_id': 'shareholders', 'count': 1}
# {'_id': 'digital inclusion', 'count': 1}
# {'_id': 'youth', 'count': 1}
# {'_id': 'frameworks', 'count': 1}
# {'_id': 'risk', 'count': 1}
# {'_id': 'Moovit', 'count': 1}
# {'_id': 'government partnerships', 'count': 1}
# {'_id': 'recognition', 'count': 1}
# {'_id': 'culture', 'count': 1}
# {'_id': 'corporate governance', 'count': 1}
# {'_id': 'impact', 'count': 1}
# {'_id': 'nonprofit', 'count': 1}
# {'_id': 'reliability', 'count': 1}
# {'_id': 'employee conduct', 'count': 1}
# {'_id': 'funding', 'count': 1}
# {'_id': 'management diversity', 'count': 1}
# {'_id': 'water reduction', 'count': 1}
# {'_id': 'pandemic leadership team', 'count': 1}
# {'_id': 'csr', 'count': 1}
# {'_id': 'conflict of interest', 'count': 1}
# {'_id': 'recognition program', 'count': 1}
# {'_id': 'accountability', 'count': 1}
# {'_id': 'incident response', 'count': 1}
# {'_id': 'tax payments', 'count': 1}
# {'_id': 'executive diversity', 'count': 1}
# {'_id': 'business strategy', 'count': 1}
# {'_id': 'sustainability goals', 'count': 1}
# {'_id': 'climate solutions', 'count': 1}
# {'_id': 'industry collaboration', 'count': 1}
# {'_id': 'corrective action plan', 'count': 1}
# {'_id': 'performance review', 'count': 1}
# {'_id': 'climate investment', 'count': 1}
# {'_id': 'pay parity', 'count': 1}
# {'_id': 'gender equality', 'count': 1}
# {'_id': 'carbon reduction', 'count': 1}
# {'_id': 'technology leadership', 'count': 1}
# {'_id': 'customer privacy', 'count': 1}
# {'_id': 'manufacturing expansion', 'count': 1}
# {'_id': 'ESG', 'count': 1}
# {'_id': 'corporate responsibility', 'count': 1}
# {'_id': 'global reach', 'count': 1}
# {'_id': 'leadership diversity', 'count': 1}
# {'_id': 'IP portfolio', 'count': 1}
# {'_id': 'supplier audits', 'count': 1}
# {'_id': 'supply chain risk', 'count': 1}
# {'_id': 'AI evangelism', 'count': 1}
# {'_id': 'sustainable growth', 'count': 1}
# {'_id': 'investor engagement', 'count': 1}
# {'_id': 'US', 'count': 1}
# {'_id': 'data availability', 'count': 1}
# {'_id': 'patents', 'count': 1}
# {'_id': 'Intel Capital', 'count': 1}
# {'_id': 'history', 'count': 1}
# {'_id': 'supplier diversity', 'count': 1}
# {'_id': 'operations', 'count': 1}
# {'_id': 'data centers', 'count': 1}
# {'_id': 'supply capacity', 'count': 1}
# {'_id': 'energy efficiency', 'count': 1}
# {'_id': 'assessments', 'count': 1}
